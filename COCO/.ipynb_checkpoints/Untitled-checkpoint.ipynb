# %%
import json
from pathlib import Path
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt

# %matplotlib inline

import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn

import model_utils
import plot_utils
import custom_transforms
from dataset import COCO_Person_Dataset
from nn_model import Net
from CONSTANTS import idx_to_keypoint_type
from custom_transforms import *

# %%
#good imids 391568, 498986, 40830
#ds length = 45,174

# %%
#17 keypoints
#'nose', 'left_eye', 'right_eye', 'left_ear', 'right_ear', 'left_shoulder', 'right_shoulder', 
#'left_elbow', 'right_elbow', 'left_wrist', 'right_wrist', 'left_hip', 'right_hip', 'left_knee', 
#'right_knee', 'left_ankle', 'right_ankle'

# %%
ds_categories = [{'supercategory': 'person', 'name': 'person', 'skeleton': [[16, 14], [14, 12], [17, 15], [15, 13], [12, 13], [6, 12], [7, 13], [6, 7], [6, 8], [7, 9], [8, 10], [9, 11], [2, 3], [1, 2], [1, 3], [2, 4], [3, 5], [4, 6], [5, 7]], 'keypoints': ['nose', 'left_eye', 'right_eye', 'left_ear', 'right_ear', 'left_shoulder', 'right_shoulder', 'left_elbow', 'right_elbow', 'left_wrist', 'right_wrist', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'left_ankle', 'right_ankle'], 'id': 1}]

img_id_to_annotations = np.load('im_id_to_keypoints.npy').ravel()[0]
img_id_to_image_info = np.load('img_id_to_annotation.npy').ravel()[0]
im_ids = list(img_id_to_annotations.keys())

# %%
tfms = transforms.Compose([
    ResizeImgAndKeypoints(),
    ColorJitter(),
    RandomGrayscale(),
    RandomFlipImgAndKeypoints(),
    RandomRotateImgAndKeypoints()
])
ds = COCO_Person_Dataset('train2014/', img_id_to_image_info, img_id_to_annotations, tfms)

# %%
103775, 383329
#np.random.randint(0,45174)

#ds idx: 32520
# Out:
# (103775, 383329)

# %%
15369

# %%
idx = np.random.randint(0,45174)
#idx = 15369, 27466, 40574
print(idx)
i, hm, paf, hm_ind, paf_ind = ds[idx]

plt.imshow(i)
plot_utils.plot_pafs(i, paf)
plot_utils.plot_heatmaps(i, hm)
# Out:
# 20535
# 101065

# %%
model = Net(in_training=True)

# %%
model.freeze_F()

# %%
model.train_paf_stage(4)

# %%
model.freeze_all_paf_stages()

# %%
model.train_hm_stage(2)

# %%
paf, hm = model(torch.ones(1,3,224,224))

# %%
len(paf)
# Out:
# 1

# %%
paf[0].shape
# Out:
# torch.Size([128, 28, 28])

# %%
pafs, heatmaps = model(torch.ones(1,3,224,224))

# %%
paf_map = np.zeros((2,2))

# %%
mask = np.array([[1,0],[0,1]])

# %%
mask
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
paf_map
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
mask[]
# Out:
# array([1, 1])

# %%
mask!=0
# Out:
# array([[ True, False],
#        [False,  True]])
